# %%
import pandas as pd

# %%
df = pd.read_csv("hr_analytics.csv")

# %%
print(df.shape)
# Out:
# (1000, 10)

# %%
rows, columns = df.shape

print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 1000
# Number of columns: 10

# %%
print(df.dtypes)
# Out:
# Age                   int64
# Gender               object
# Department           object
# MonthlyIncome         int64
# TotalWorkingYears     int64
# YearsAtCompany        int64
# JobSatisfaction       int64
# WorkLifeBalance       int64
# OverTime             object
# Attrition            object
# dtype: object

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      Age  Gender Department  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# 0     50  Female         HR           4753                 14               8
# 1     36    Male        R&D          13123                  3               7
# 2     29    Male         HR          19376                 16              15
# 3     42    Male         HR           9588                 19              14
# 4     40    Male        R&D           9304                 18               8
# ..   ...     ...        ...            ...                ...             ...
# 995   34  Female      Sales           7986                  2               5
# 996   51  Female      Sales           4481                 26              12
# 997   44    Male         HR           6731                 27               6
# 998   40  Female      Sales          19835                 27               9
# 999   53  Female         HR          13758                 15               1
#
# ...

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %%
print(df.duplicated().any())
# Out:
# False

# %%
print("Number of employees:", df.shape[0])
# Out:
# Number of employees: 1000

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'Gender', 'Department', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'JobSatisfaction', 'WorkLifeBalance', 'OverTime', 'Attrition']

# %%
print(df["Department"].nunique())
# Out:
# 3

# %%
print(df["Department"].unique())
# Out:
# ['HR' 'R&D' 'Sales']

# %%
average_age = df["Age"].mean()
print(f"Average Employee Age: {average_age:.2f} years")
# Out:
# Average Employee Age: 40.95 years

# %%
min_age = df["Age"].min()
max_age = df["Age"].max()

print(f"Minimum Employee Age: {min_age}")
print(f"Maximum Employee Age: {max_age}")
# Out:
# Minimum Employee Age: 22
# Maximum Employee Age: 59

# %%
gender_distribution = df["Gender"].value_counts()
print(gender_distribution)
# Out:
# Gender
# Male      504
# Female    496
# Name: count, dtype: int64

# %%
department_counts = df["Department"].value_counts()
print(department_counts)
# Out:
# Department
# HR       352
# Sales    343
# R&D      305
# Name: count, dtype: int64

# %%
employees_more_than_10 = df[df["TotalWorkingYears"] > 10]
print(len(employees_more_than_10))
# Out:
# 720

# %%
employees_more_than_5 = df[df["YearsAtCompany"] > 5]
print(len(employees_more_than_5))
# Out:
# 752

# %%
average_income = df.groupby("Department")["MonthlyIncome"].mean()
print(average_income)
# Out:
# Department
# HR       11604.042614
# R&D      11461.272131
# Sales    11417.247813
# Name: MonthlyIncome, dtype: float64

# %%
average_income = df.groupby("Department")["MonthlyIncome"].mean().round(2)
print(average_income)
# Out:
# Department
# HR       11604.04
# R&D      11461.27
# Sales    11417.25
# Name: MonthlyIncome, dtype: float64

# %%
employees_left = df[df["Attrition"] == "Yes"]
left_by_department = employees_left["Department"].value_counts()
print(left_by_department)
# Out:
# Department
# R&D      74
# HR       70
# Sales    59
# Name: count, dtype: int64
